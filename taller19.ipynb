# %% [markdown]
# # Taller 19 - Programación Funcional sobre Vectores
#
# Primer Integrante:
#
# Segundo Integrante:

# %% [markdown]
# ## Primero lo primero
#
# ESTE TALLER DEBERÁ DESARROLLARSE EN EL LENGUAJE PYTHON. ESTÁ PROHIBIDO USAR ESTRUCTURAS DE
# DATOS PROPIAS DEL LENGUAJE COMO SON LAS LISTAS, TUPLAS, CONJUNTOS O DICCIONARIOS.
# DEBE USAR LOS VECTORES VISTOS EN CLASE. NO SE ACEPTA NINGUNA OTRA IMPLEMENTACIÓN.
# TODOS LOS EJERCICIOS SE DEBEN REALIZAR EN PYTHON CON PROGRAMACIÓN FUNCIONAL.
# NO HAY RECURSIÓN NI WHILE NI FOR. ACUERDESE
# QUE LA PALABRA **NONE** ESTÁ PROHIBIDA TAMBIÉN. NO OLVIDE ESCRIBIR EL TIPO DE TODOS LOS
# **DATOS DE ENTRADA** Y DE TODOS LOS DATOS DE SALIDA TAMBIÉN.
#
# ESTE TRABAJO SE PUEDE DESARROLLAR EN PAREJAS.
#
# EJECUTE EL SIGUIENTE CÓDIGO ANTES DE TODO PARA TRAER LA LIBRERIA DE LA EAN.

# %%
# Ejecute este código primero antes que todo para trabajar con las estructuras de datos

# !rm ean.py
# !wget https://github.com/ean-ds-2026-s1/taller19/raw/refs/heads/main/ean.py

# %% [markdown]
# Las funciones que va a escribir trabajan con vectores de Personas, los cuales
# se pueden apreciar en el siguiente diagrama de clases:
#
# ![Clase Persona](https://github.com/ean-ds-2026-s1/taller18/blob/main/clase-persona.png?raw=true)

# %% [markdown]
# ---
#
# ### Prueba 01: Contar Mujeres
#
# Esciba una función externa en Python llamado `prueba01`, que reciba un vector
# de personas llamado `vec_personas`, y que retorne cuántas mujeres
# tienen un nombre terminado en vocal en mayúscula. Use funciones de
# orden superior sobre vectores.

# %%
from ean import *

# Prueba 01
def prueba01(vec_personas: "Vec2_de_Personas") -> int:
    pass

# %% [markdown]
# ---
# Pruebas de la función de `prueba01`

# %%
import unittest
from ean import *
from inspect import signature

# Prueba de Ejercicio01
class TestPrueba01(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(prueba01), "vec_personas", ("Persona",), tipo_retorno="int"):
            vec = vector_personas()
            self.assertEqual(prueba01(vec), 36)

            vecx = vec.slice(90, 350)
            self.assertEqual(prueba01(vecx), 8)

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestPrueba01'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 02: Buscar persona por cédula
#
# Escriba una función externa en Python llamada `buscar_persona`, que reciba dos parámetros:
# el primer parámetro es un vector de personas (vectores como los vistos en clases)
# llamado `personas`.
# El segundo parámetro se llama `cedula_persona`, un número entero. La función debe
# buscar y retornar el nombre de la persona que tiene esa cédula. Retorne la palabra `"NO EXISTE"`
# cuando no encontremos una persona con esa cédula. Use iteradores para recorrer el vector. No use
# la función `upper`.

# %%
from ean import *

# Buscar una persona por cédula
def buscar_persona(personas: "Vec2_de_Personas", cedula_persona: int) -> str:
    pass

# %% [markdown]
# ---
# Prueba del ejercicio `buscar_persona`

# %%
import unittest
from ean import *
from inspect import signature

# Prueba de Ejercicio02
class TestEjercicio02(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(buscar_persona), "personas", ("Persona",), tipo_retorno="str"):
            ap = vector_personas()
            persona = buscar_persona(personas=ap, cedula_persona=1_616_153_485)
            self.assertEqual(type(persona).__name__, "str")
            self.assertEqual(persona, "Robert Beck".upper())

            persona = buscar_persona(ap, 1_111_111_111)
            self.assertEqual(persona, "NO EXISTE")

            persona = buscar_persona(ap, 1_536_842_169)
            self.assertEqual(persona, "Elizabeth Miller".upper())

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")



# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio02'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# ### Ejercicio 03: Promedio de peso
#
# Escriba una función externa en Python llamada `promedio_personas`, que reciba un vector
# de personas llamado `personas` y que retorne el promedio del peso de las mujeres que hayan
# estudiado en la universidad o que hayan realizado un postgrado y que no tienen hijos.

# %%
from ean import *

# Definición de la función de buscar un carro
def promedio_personas(personas: "Vec2_de_Personas") -> float:
    pass

# %% [markdown]
# ---
# Prueba de la función de `promedio_personas`

# %%
import unittest
from ean import *
from inspect import signature

# Prueba de Ejercicio03
class TestEjercicio03(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(promedio_personas), "personas", ("Persona",), tipo_retorno="float"):
            vp = vector_personas()
            self.assertAlmostEqual(promedio_personas(vp), 76.2414, places=4)

            vp1 = vp.slice(0, 40)
            self.assertEqual(promedio_personas(vp1), 0.0)

            vp2 = vp.slice(40, 280)
            self.assertEqual(promedio_personas(vp2), 65.5)

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio03'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# ### Ejercicio 04: El más joven
#
# Escriba una función externa en Python llamada `mas_joven` que reciba un vector de personas llamado `vector`
# y que, retorne el nombre de la persona más joven que tenga una cédula par, no es fumadora pero tiene carro.
# Retorne la `"INEXISTENTE"` si no se encuentra esta persona. No puede aparecer la función `upper`.

# %%
from ean import *

# Definición de la función `mas_joven`

# %% [markdown]
# ---
# Prueba del ejercicio `mas_joven`

# %%
import unittest
from ean import *
from inspect import signature

class TestEjercicio04(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(mas_joven), "vector", ("Persona",), tipo_retorno="str"):
            vp = vector_personas()
            self.assertEqual(mas_joven(vp), "NICHOLAS MARTIN")

            vp1 = vp.slice(0, 40)
            self.assertEqual(mas_joven(vp1), "ARTHUR HAWKINS")

            vp2 = vp.slice(280, 290)
            self.assertEqual(mas_joven(vp2), "HEATHER TERRELL")

            vp3 = vp.slice(290, 300)
            self.assertEqual(mas_joven(vp3), "INEXISTENTE")

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")

# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio04'], verbosity=2, exit=False);

# %% [markdown]
# ---
#
# ### Ejercicio 05: Es par el nombre de la persona con mayor imc
#
# Escriba una función en Python llamada `persona_mas_obesa` que reciba dos parámetros.
# El primer parámetro es un vector de personas llamado `personas`. El segundo parámetro
# es un número entero llamado `estrato`. La función que va a escribir deberá retornar
# la palabra `"SI"` si el nombre de la persona con mayor IMC y que vive en el estrato
# recibido como parámetro, tiene una cantidad par de letras en su nombre. Retorne
# `"NO"` cuando la nombre de la persona con el mayor IMC que vive en el estrato
# recibido como parámetro tiene una cantidad impar de letras. Retorne `"VACIO"`
# cuando no se encuentra ninguna persona con ese estrato. Use iteradores para recorrer el vector.
# No puede usar la función `upper`.

# %%
from ean import *

# Definición de la función del ejercicio 05

# %% [markdown]
# ---
# Prueba del ejercicio de la persona más obesa con número par de letras

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 05
class TestEjercicio05(unittest.TestCase):
    def test_ejercicio05(self):
        if verificar_params_funcion(signature(persona_mas_obesa), "personas", ("Persona",), tipo_retorno="str"):
            lp = vector_personas()
            self.assertEqual(persona_mas_obesa(lp, 1), "VACIO")
            self.assertEqual(persona_mas_obesa(lp, 2), "SI")
            self.assertEqual(persona_mas_obesa(lp, 3), "NO")
            self.assertEqual(persona_mas_obesa(lp, 4), "SI")
            self.assertEqual(persona_mas_obesa(lp, 5), "VACIO")
            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio05'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 06: mujeres con un hijo
#
# Escriba una función externa en Python llamada `prueba06` que
# reciba un vector de personas llamado `vec_personas` y que
# retorne un vector de `str` con los nombres de las mujeres
# que tienen al menos un hijo y cuyos ingresos superan los
# 5 millones de pesos y que hayan estudiado en la universidad
# o hayan hecho un postgrado.

# %%
from ean import *

# Ejercicio 06
def prueba06(vec_personas: "Vec2_de_Personas") -> "Vec2_de_str":
    pass

# %% [markdown]
# ---
# Prueba del ejercicio 06

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 06
class TestEjercicio06(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(prueba06), "vec_personas", ("Persona",), tipo_retorno="Vec2_de_str"):
            lp = vector_personas()
            resp = prueba06(lp)
            resp.bsort()
            otra = vec2("AMY CLARK", "ANGELA HALL", "ANGELA WALKER", "COURTNEY SLOAN", "ELIZABETH WILLIAMS MD",
                        "EMILY BLAKE", "ERIN WHEELER", "KIMBERLY BRADLEY", "LAURA WATTS", "LISA SIMMONS",
                        "MRS. AMY TAYLOR MD", "NICOLE LEWIS", "SHANNON REYNOLDS", "TRACY THOMPSON")
            self.assertEqual(resp, otra)

            resp2 = prueba06(lp.slice(200, 300))
            resp2.bsort()
            self.assertEqual(resp2, vec2("COURTNEY SLOAN", "NICOLE LEWIS"))

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio06'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 07: hombres obesos
#
# Escribir una función externa en Python llamada `hombres_obesos` que reciba un sólo
# parámetro llamado `personas` que es un vector de personas y que retorna un vector
# de números enteros con las cédulas de los hombres obesos (imc >= 30) que nacieron
# hace 55 años o más.

# %%
from ean import *

# Definición del ejercicio 07

# %% [markdown]
# ---
# Prueba del ejercicio 07

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 07
class TestEjercicio07(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(hombres_obesos), "personas", ("Persona",), tipo_retorno="Vec2_de_int"):
            lp = vector_personas()
            resp = hombres_obesos(lp)
            resp.bsort()
            otra = vec2(1381878413, 1538042950, 1663973190, 1762165104, 1839033016)
            self.assertEqual(resp, otra)

            resp2 = hombres_obesos(lp.slice(100, 200))
            resp2.bsort()
            self.assertEqual(resp2, vec2(1538042950, 1663973190, 1762165104))

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio07'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 08: Cantidad de hombres
#
# Escribir una función externa en python, llamada `cant_hombres` que reciba un
# vector de personas llamado `personas` y que retorne la cantidad de hombres en
# el vector que nacieron en la década del 60 del siglo pasado. **SOLO PUEDE TRABAJAR
# CON PROGRAMACIÓN FUNCIONAL, NO HAY FOR NI WHILE.**

# %%
from ean import *

# Definición de la función cant_hombres

# %% [markdown]
# ---
# Prueba del ejercicio `cant_hombres`

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 08
class TestEjercicio08(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(cant_hombres), "personas", ("Persona",), tipo_retorno="int"):
            lp = vector_personas()
            self.assertEqual(11, cant_hombres(lp))

            lp = lp.slice(100, 200)
            self.assertEqual(9, cant_hombres(lp))

            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio08'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 09: Promedio personas
#
# Escriba una función externa en Python llamada `prom_personas` que reciba
# un vector de personas llamado `personas` y un número entero llamado `estrato`,
# y que retorne la suma de los ingresos de las personas del vector que tienen casa,
# usan lentes, no tienen automóvil y que no viven en el estrato recibido como parámetro.
# **USE SOLAMENTE PROGRAMACIÓN FUNCIONAL.**

# %%
from ean import *

# Definición de la función del ejercicio09
def prom_personas(personas: "Vec2_de_Personas", estrato: int) -> int:
    pass

# %% [markdown]
# ---
# Prueba del ejercicio `prom_personas`

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 09
class TestEjercicio09(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(prom_personas), "personas", ("Persona",), tipo_retorno="int"):
            lp = vector_personas()
            self.assertEqual(263_961_000.0, prom_personas(lp, 1))
            self.assertEqual(174_727_000.0, prom_personas(lp, 2))
            self.assertEqual(166_736_000.0, prom_personas(lp, 3))
            self.assertEqual(186_459_000.0, prom_personas(lp, 4))
            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio09'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 10: cantidad de hombres
#
# Escriba una función externa en Python llamada `ejercicio10` que recibe tres datos de entrada. El primer
# parámetro es un vector de personas llamado `personas`; el segundo parámetro es un número entero llamado
# `edad`; el tercer parámetro es un número entero llamado `estrato`. La función debe, usando solamente
# programación funcional(no for ni while), retornar la cantidad de hombres con ingresos entre 2 y 3 millones
# de pesos y con una edad entre 30 años y la edad que se reciba como parámetro y que viven en el estrato
# recibido como parámetro y cuyo nombre no termina en vocal en mayúsculas y la cédula no termina en 0.

# %%
from ean import *

# Definición del ejercicio 10

# %% [markdown]
# ---
# Prueba del `ejercicio10`

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 10
class TestEjercicio10(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(ejercicio10), "personas", ("Persona",), tipo_retorno="int"):
            personas = vector_personas()
            self.assertEqual(ejercicio10(personas, edad=20, estrato=1), 0)
            self.assertEqual(ejercicio10(personas, 20, 2), 0)
            self.assertEqual(ejercicio10(personas, 20, 3), 0)
            self.assertEqual(ejercicio10(personas, 30, 2), 0)
            self.assertEqual(ejercicio10(personas, 30, 3), 0)
            self.assertEqual(ejercicio10(personas, 30, 4), 1)
            self.assertEqual(ejercicio10(personas, 40, 2), 6)
            self.assertEqual(ejercicio10(personas, 40, 3), 4)
            self.assertEqual(ejercicio10(personas, 40, 4), 1)
            self.assertEqual(ejercicio10(personas, 60, 2), 10)
            self.assertEqual(ejercicio10(personas, 60, 3), 15)
            self.assertEqual(ejercicio10(personas, 60, 4), 6)
            self.assertEqual(ejercicio10(personas, 60, 5), 0)
            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio10'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 11: Porcentaje
#
# Escriba una función en Python llamada `ejercicio11` que va a recibir los siguientes parámetros:
# el primer parámetro es un vector de personas llamado `personas`; el segundo parámetro es un `str`
# llamado `genero` (este parámetro puede ser igual a `"MASC"` para hombres y a `"FEM"` para mujeres)
# ; el tercer parámetro es un número entero llamado `estrato`. La función deberá
# retornar un número real (`float`) que corresponde al porcentaje de personas del género recibido
# como parámetro, sean fumadoras, sin hijos y que viven en el estrato que se recibe como parámetro.
# Use programación funcional.

# %%
from ean import *

# Definición de la función ejercicio11

# %% [markdown]
# ---
# Prueba del ejercicio `ejercicio11`

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 11
class TestEjercicio11(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(ejercicio11), "personas", ("Persona",), tipo_retorno="float"):
            personas = vector_personas()
            self.assertAlmostEqual(2.3121, ejercicio11(personas, genero="MASC", estrato=2), places=4)
            self.assertAlmostEqual(1.9268, ejercicio11(personas, "MASC", 3), places=4)
            self.assertAlmostEqual(3.2755, ejercicio11(personas, "MASC", 4), places=4)
            self.assertAlmostEqual(2.3121, ejercicio11(personas, "FEM", 2), places=4)
            self.assertAlmostEqual(1.9268, ejercicio11(personas, "FEM", 3), places=4)
            self.assertAlmostEqual(2.3121, ejercicio11(personas, "FEM", 4), places=4)
            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio11'], verbosity=2, exit=False);

# %% [markdown]
# ---
# ### Ejercicio 12: Menos pesado
#
# Escriba una función externa en Python llamada `ejercicio12` que va a recibir como datos
# de entrada: un vector de personas llamado `personas` y 3 números enteros llamados `ced1`,
# `ced2` y `ced3` (tres números de cédula). La función debe retornar el número 1 si la
# persona con la cédula `ced1` tiene un peso inferior al peso de las personas con `ced2` y
# `ced3`; la función va a retorna 2 si la persona con cédula `ced2` es la menos pesada
# de las 3; retorne 3 si la persona con cédula `ced3` es la menos pesada de las tres
# personas; retorne cero en cualquier otro caso. **SOLO PUEDE USAR PROGRAMACIÓN FUNCIONAL**.

# %%
from ean import *

# Definición de la función ejercicio12
def ejercicio12(personas: "Vec2_de_Personas", ced1: int, ced2: int, ced3: int) -> int:
    pass

# %% [markdown]
# ---
# Prueba del `ejercicio12`

# %%
import unittest
from ean import *
from inspect import signature

# Pruebas del ejercicio 12
class TestEjercicio12(unittest.TestCase):
    def test_ejercicio(self):
        if verificar_params_funcion(signature(ejercicio12), "personas", ("Persona",), tipo_retorno="int"):
            personas = vector_personas()
            self.assertEqual(2, ejercicio12(personas, personas(500).cedula, personas(200).cedula, personas(35).cedula))
            self.assertEqual(1, ejercicio12(personas, personas(200).cedula, personas(500).cedula, personas(35).cedula))
            self.assertEqual(3, ejercicio12(personas, personas(35).cedula, personas(500).cedula, personas(200).cedula))
            self.assertEqual(0, ejercicio12(personas, personas(500).cedula, personas(500).cedula, personas(500).cedula))
            print("Prueba superada 👍🏽")
        else:
            self.fail("No escribiste el método como se solicitó en el enunciado! 🤔")


# ---------------------------------------------------------------------------
unittest.main(argv=['', '-v', 'TestEjercicio12'], verbosity=2, exit=False);
